# %% [markdown]
# ## Paso 5: Técnica de los K Vecinos más Cercanos

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import OrdinalEncoder
from itertools import combinations
import time

def preprocess_data(df):
    # Imputar valores ausentes con la moda de cada columna
    df.fillna(df.mode().iloc[0], inplace=True)
    
    # Gestión de datos categóricos de tipo ordinal: se tratarán a través de la técnica de Ordinal Encoder
    ordinal_encoder = OrdinalEncoder()
    df[['loan_grade']] = ordinal_encoder.fit_transform(df[['loan_grade']])

    # Se utilizarán el 75% de los datos para construir el modelo y el 25% restante para validar el modelo construido
    X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['loan_status']), df['loan_status'], test_size=0.25, random_state=42)
    
    return X_train, X_test, y_train, y_test, ordinal_encoder

def generate_knn_dataframe(df, cols, k, ordinal_encoder):
    X = df[list(cols)]
    y = df['loan_status']

    # Normalizar o estandarizar los datos si es necesario (en este caso, no se necesita)
    # No se realiza ninguna transformación en los datos

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

    start_time_model_generation = time.time()
    # Se crea y entrena el modelo de clasificación de K Vecinos más Cercanos
    knn_classifier = KNeighborsClassifier(n_neighbors=k)
    model = knn_classifier.fit(X_train, y_train)
    model_generation_time = time.time() - start_time_model_generation

    start_time_model_testing = time.time()
    # Se predicen las salidas de datos de prueba
    y_test_pred = model.predict(X_test)

    # Se calculan las métricas para evaluar el modelo de clasificación
    mc = confusion_matrix(y_test, y_test_pred)
    e = accuracy_score(y_test, y_test_pred)
    p = precision_score(y_test, y_test_pred)
    s = recall_score(y_test, y_test_pred)
    f1 = f1_score(y_test, y_test_pred)
    model_testing_time = time.time() - start_time_model_testing

    return mc, e, p, s, f1, model_generation_time, model_testing_time

if __name__ == "__main__":
    # Se cargan los datos en un DataFrame
    df = pd.read_csv("datos/credit_risk_dataset.csv")

    # Se generan todas las combinaciones posibles de columnas
    todas_columnas = ['person_age', 'person_income', 'cb_person_cred_hist_length', 'loan_grade']
    combinaciones_columnas = []
    for r in range(1, len(todas_columnas) + 1):
        combinaciones_columnas.extend(combinations(todas_columnas, r))

    # Se definen los valores de k para los vecinos más cercanos
    valores_k = [1, 2, 3]

    # Preprocesamiento de datos
    start_time_preprocessing = time.time()
    X_train, X_test, y_train, y_test, ordinal_encoder = preprocess_data(df)
    preprocessing_time = time.time() - start_time_preprocessing
    print("Tiempo de preprocesamiento:", preprocessing_time)

    # Se itera sobre cada valor de k
    for k in valores_k:
        print(f"Resultados para K={k}:")
        
        # Se itera sobre cada combinación de columnas
        for cols in combinaciones_columnas:
            mc, e, p, s, f1, model_generation_time, model_testing_time = generate_knn_dataframe(df, cols, k, ordinal_encoder)

            # Mostrar resultados
            print(f"Columnas: {cols}")
            print('Matriz de Confusión (MC):\n', mc)
            print('Exactitud (E):', e)
            print('Precisión (P):', p)
            print('Sensibilidad (S):', s)
            print('F1 Score (F1):', f1)
            print('Tiempo de generación del modelo:', model_generation_time)
            print('Tiempo de prueba del modelo:', model_testing_time)
            print('-' * 50)
# Out:
# Tiempo de preprocesamiento: 0.02602362632751465
# Resultados para K=1:
# Columnas: ('person_age',)
# Matriz de Confusión (MC):
#  [[4952 1379]
#  [1458  357]]
# Exactitud (E): 0.6517309108765038
# Precisión (P): 0.2056451612903226
# Sensibilidad (S): 0.19669421487603306
# F1 Score (F1): 0.20107012109265
# Tiempo de generación del modelo: 0.006216764450073242
# Tiempo de prueba del modelo: 0.4571671485900879
# --------------------------------------------------
# Columnas: ('person_income',)
# Matriz de Confusión (MC):
#  [[4830 1501]
#  [ 905  910]]
# Exactitud (E): 0.7046403142646698
# Precisión (P): 0.37743674823724593
# Sensibilidad (S): 0.5013774104683195
# F1 Score (F1): 0.4306672976810222
# Tiempo de generación del modelo: 0.006993770599365234
# Tiempo de prueba del modelo: 0.33016037940979004
# --------------------------------------------------
# Columnas: ('cb_person_cred_hist_length',)
# Matriz de Confusión (MC):
#  [[4694 1637]
#  [1329  486]]
# Exactitud (E): 0.6358949177510435
# Precisión (P): 0.2289213377296279
# Sensibilidad (S): 0.26776859504132233
# F1 Score (F1): 0.24682579989842562
# Tiempo de generación del modelo: 0.0069925785064697266
# Tiempo de prueba del modelo: 0.5548830032348633
# --------------------------------------------------
# Columnas: ('loan_grade',)
# Matriz de Confusión (MC):
#  [[4555 1776]
#  [ 695 1120]]
# Exactitud (E): 0.6966609378836238
# Precisión (P): 0.3867403314917127
# Sensibilidad (S): 0.6170798898071626
# F1 Score (F1): 0.475482912332838
# Tiempo de generación del modelo: 0.005979299545288086
# Tiempo de prueba del modelo: 0.6594324111938477
# --------------------------------------------------
# Columnas: ('person_age', 'person_income')
# Matriz de Confusión (MC):
#  [[5375  956]
#  [1054  761]]
# Exactitud (E): 0.753253130370734
# Precisión (P): 0.44321490972626676
# Sensibilidad (S): 0.4192837465564738
# F1 Score (F1): 0.4309173272933182
# Tiempo de generación del modelo: 0.009153366088867188
# Tiempo de prueba del modelo: 0.3271610736846924
# --------------------------------------------------
# Columnas: ('person_age', 'cb_person_cred_hist_length')
# Matriz de Confusión (MC):
#  [[4483 1848]
#  [1263  552]]
# Exactitud (E): 0.6180947704394795
# Precisión (P): 0.23
# Sensibilidad (S): 0.30413223140495865
# F1 Score (F1): 0.2619217081850534
# Tiempo de generación del modelo: 0.011257171630859375
# Tiempo de prueba del modelo: 0.3569676876068115
# --------------------------------------------------
# Columnas: ('person_age', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5118 1213]
#  [1172  643]]
# Exactitud (E): 0.7072182666339307
# Precisión (P): 0.3464439655172414
# Sensibilidad (S): 0.35426997245179065
# F1 Score (F1): 0.3503132661400164
# Tiempo de generación del modelo: 0.011266231536865234
# Tiempo de prueba del modelo: 0.35544371604919434
# --------------------------------------------------
# Columnas: ('person_income', 'cb_person_cred_hist_length')
# Matriz de Confusión (MC):
#  [[5181 1150]
#  [1015  800]]
# Exactitud (E): 0.7342253866928554
# Precisión (P): 0.41025641025641024
# Sensibilidad (S): 0.44077134986225897
# F1 Score (F1): 0.42496679946879146
# Tiempo de generación del modelo: 0.010151863098144531
# Tiempo de prueba del modelo: 0.3318490982055664
# --------------------------------------------------
# Columnas: ('person_income', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5338  993]
#  [ 865  950]]
# Exactitud (E): 0.7719125951387183
# Precisión (P): 0.4889346371590324
# Sensibilidad (S): 0.5234159779614325
# F1 Score (F1): 0.5055880787653007
# Tiempo de generación del modelo: 0.01172327995300293
# Tiempo de prueba del modelo: 0.3328876495361328
# --------------------------------------------------
# Columnas: ('cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[4741 1590]
#  [ 953  862]]
# Exactitud (E): 0.6878222440461577
# Precisión (P): 0.35154975530179444
# Sensibilidad (S): 0.474931129476584
# F1 Score (F1): 0.40403093508319665
# Tiempo de generación del modelo: 0.011182546615600586
# Tiempo de prueba del modelo: 0.38528943061828613
# --------------------------------------------------
# Columnas: ('person_age', 'person_income', 'cb_person_cred_hist_length')
# Matriz de Confusión (MC):
#  [[5379  952]
#  [1041  774]]
# Exactitud (E): 0.7553400441934692
# Precisión (P): 0.4484356894553882
# Sensibilidad (S): 0.42644628099173554
# F1 Score (F1): 0.43716464275628353
# Tiempo de generación del modelo: 0.01338958740234375
# Tiempo de prueba del modelo: 0.3368873596191406
# --------------------------------------------------
# Columnas: ('person_age', 'person_income', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5508  823]
#  [ 916  899]]
# Exactitud (E): 0.786520991897864
# Precisión (P): 0.5220673635307782
# Sensibilidad (S): 0.4953168044077135
# F1 Score (F1): 0.5083404014701726
# Tiempo de generación del modelo: 0.015250444412231445
# Tiempo de prueba del modelo: 0.33547186851501465
# --------------------------------------------------
# Columnas: ('person_age', 'cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5310 1021]
#  [1164  651]]
# Exactitud (E): 0.7317701939602259
# Precisión (P): 0.38935406698564595
# Sensibilidad (S): 0.3586776859504132
# F1 Score (F1): 0.37338686550043015
# Tiempo de generación del modelo: 0.017400264739990234
# Tiempo de prueba del modelo: 0.35671257972717285
# --------------------------------------------------
# Columnas: ('person_income', 'cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5445  886]
#  [ 936  879]]
# Exactitud (E): 0.7763319420574515
# Precisión (P): 0.4980169971671388
# Sensibilidad (S): 0.484297520661157
# F1 Score (F1): 0.4910614525139665
# Tiempo de generación del modelo: 0.015161275863647461
# Tiempo de prueba del modelo: 0.3300440311431885
# --------------------------------------------------
# Columnas: ('person_age', 'person_income', 'cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5530  801]
#  [ 922  893]]
# Exactitud (E): 0.7884851460839676
# Precisión (P): 0.5271546635182999
# Sensibilidad (S): 0.4920110192837466
# F1 Score (F1): 0.5089769165004274
# Tiempo de generación del modelo: 0.016956567764282227
# Tiempo de prueba del modelo: 0.3437385559082031
# --------------------------------------------------
# Resultados para K=2:
# Columnas: ('person_age',)
# Matriz de Confusión (MC):
#  [[6301   30]
#  [1809    6]]
# Exactitud (E): 0.7742450282347164
# Precisión (P): 0.16666666666666666
# Sensibilidad (S): 0.003305785123966942
# F1 Score (F1): 0.006482982171799027
# Tiempo de generación del modelo: 0.0069980621337890625
# Tiempo de prueba del modelo: 0.417125940322876
# --------------------------------------------------
# Columnas: ('person_income',)
# Matriz de Confusión (MC):
#  [[5877  454]
#  [1303  512]]
# Exactitud (E): 0.7843113184384974
# Precisión (P): 0.5300207039337475
# Sensibilidad (S): 0.2820936639118457
# F1 Score (F1): 0.368212873067242
# Tiempo de generación del modelo: 0.007006406784057617
# Tiempo de prueba del modelo: 0.3398735523223877
# --------------------------------------------------
# Columnas: ('cb_person_cred_hist_length',)
# Matriz de Confusión (MC):
#  [[5175 1156]
#  [1459  356]]
# Exactitud (E): 0.6789835502086914
# Precisión (P): 0.23544973544973544
# Sensibilidad (S): 0.19614325068870522
# F1 Score (F1): 0.21400661256387135
# Tiempo de generación del modelo: 0.0061914920806884766
# Tiempo de prueba del modelo: 0.4990720748901367
# --------------------------------------------------
# Columnas: ('loan_grade',)
# Matriz de Confusión (MC):
#  [[5875  456]
#  [1090  725]]
# Exactitud (E): 0.8102136017677388
# Precisión (P): 0.6138865368331922
# Sensibilidad (S): 0.39944903581267216
# F1 Score (F1): 0.48397863818424564
# Tiempo de generación del modelo: 0.006181478500366211
# Tiempo de prueba del modelo: 0.6728088855743408
# --------------------------------------------------
# Columnas: ('person_age', 'person_income')
# Matriz de Confusión (MC):
#  [[6004  327]
#  [1409  406]]
# Exactitud (E): 0.7868892708077584
# Precisión (P): 0.5538881309686221
# Sensibilidad (S): 0.2236914600550964
# F1 Score (F1): 0.31868131868131866
# Tiempo de generación del modelo: 0.009157180786132812
# Tiempo de prueba del modelo: 0.3301255702972412
# --------------------------------------------------
# Columnas: ('person_age', 'cb_person_cred_hist_length')
# Matriz de Confusión (MC):
#  [[6009  322]
#  [1710  105]]
# Exactitud (E): 0.7505524183648417
# Precisión (P): 0.2459016393442623
# Sensibilidad (S): 0.05785123966942149
# F1 Score (F1): 0.0936663693131133
# Tiempo de generación del modelo: 0.011208534240722656
# Tiempo de prueba del modelo: 0.36233973503112793
# --------------------------------------------------
# Columnas: ('person_age', 'loan_grade')
# Matriz de Confusión (MC):
#  [[6215  116]
#  [1602  213]]
# Exactitud (E): 0.789098944267125
# Precisión (P): 0.6474164133738601
# Sensibilidad (S): 0.11735537190082644
# F1 Score (F1): 0.19869402985074627
# Tiempo de generación del modelo: 0.011201858520507812
# Tiempo de prueba del modelo: 0.37697315216064453
# --------------------------------------------------
# Columnas: ('person_income', 'cb_person_cred_hist_length')
# Matriz de Confusión (MC):
#  [[5990  341]
#  [1423  392]]
# Exactitud (E): 0.7834520009820771
# Precisión (P): 0.5347885402455662
# Sensibilidad (S): 0.2159779614325069
# F1 Score (F1): 0.3076923076923077
# Tiempo de generación del modelo: 0.010222911834716797
# Tiempo de prueba del modelo: 0.34200382232666016
# --------------------------------------------------
# Columnas: ('person_income', 'loan_grade')
# Matriz de Confusión (MC):
#  [[6026  305]
#  [1201  614]]
# Exactitud (E): 0.8151239872329978
# Precisión (P): 0.6681175190424374
# Sensibilidad (S): 0.33829201101928374
# F1 Score (F1): 0.44915874177029985
# Tiempo de generación del modelo: 0.01214146614074707
# Tiempo de prueba del modelo: 0.33905601501464844
# --------------------------------------------------
# Columnas: ('cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[6081  250]
#  [1363  452]]
# Exactitud (E): 0.8019887061134299
# Precisión (P): 0.6438746438746439
# Sensibilidad (S): 0.2490358126721763
# F1 Score (F1): 0.3591577274533174
# Tiempo de generación del modelo: 0.012222528457641602
# Tiempo de prueba del modelo: 0.39362120628356934
# --------------------------------------------------
# Columnas: ('person_age', 'person_income', 'cb_person_cred_hist_length')
# Matriz de Confusión (MC):
#  [[5993  338]
#  [1390  425]]
# Exactitud (E): 0.7878713479008103
# Precisión (P): 0.5570117955439057
# Sensibilidad (S): 0.23415977961432508
# F1 Score (F1): 0.3297129557796742
# Tiempo de generación del modelo: 0.01237797737121582
# Tiempo de prueba del modelo: 0.33791470527648926
# --------------------------------------------------
# Columnas: ('person_age', 'person_income', 'loan_grade')
# Matriz de Confusión (MC):
#  [[6082  249]
#  [1254  561]]
# Exactitud (E): 0.8154922661428922
# Precisión (P): 0.6925925925925925
# Sensibilidad (S): 0.3090909090909091
# F1 Score (F1): 0.4274285714285714
# Tiempo de generación del modelo: 0.014811038970947266
# Tiempo de prueba del modelo: 0.33751916885375977
# --------------------------------------------------
# Columnas: ('person_age', 'cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[6072  259]
#  [1447  368]]
# Exactitud (E): 0.7905720599067027
# Precisión (P): 0.5869218500797448
# Sensibilidad (S): 0.20275482093663913
# F1 Score (F1): 0.3013923013923014
# Tiempo de generación del modelo: 0.016433000564575195
# Tiempo de prueba del modelo: 0.36366748809814453
# --------------------------------------------------
# Columnas: ('person_income', 'cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[6075  256]
#  [1277  538]]
# Exactitud (E): 0.8118094770439479
# Precisión (P): 0.6775818639798489
# Sensibilidad (S): 0.29641873278236913
# F1 Score (F1): 0.41241855116903026
# Tiempo de generación del modelo: 0.014194965362548828
# Tiempo de prueba del modelo: 0.3373425006866455
# --------------------------------------------------
# Columnas: ('person_age', 'person_income', 'cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[6063  268]
#  [1297  518]]
# Exactitud (E): 0.8078811686717408
# Precisión (P): 0.6590330788804071
# Sensibilidad (S): 0.28539944903581266
# F1 Score (F1): 0.39830834294502104
# Tiempo de generación del modelo: 0.016842365264892578
# Tiempo de prueba del modelo: 0.33762621879577637
# --------------------------------------------------
# Resultados para K=3:
# Columnas: ('person_age',)
# Matriz de Confusión (MC):
#  [[4842 1489]
#  [1396  419]]
# Exactitud (E): 0.6458384483181929
# Precisión (P): 0.21960167714884696
# Sensibilidad (S): 0.23085399449035812
# F1 Score (F1): 0.22508729519204942
# Tiempo de generación del modelo: 0.006194114685058594
# Tiempo de prueba del modelo: 0.46551966667175293
# --------------------------------------------------
# Columnas: ('person_income',)
# Matriz de Confusión (MC):
#  [[5493  838]
#  [1038  777]]
# Exactitud (E): 0.7697029216793518
# Precisión (P): 0.48111455108359136
# Sensibilidad (S): 0.428099173553719
# F1 Score (F1): 0.4530612244897959
# Tiempo de generación del modelo: 0.00699615478515625
# Tiempo de prueba del modelo: 0.33223986625671387
# --------------------------------------------------
# Columnas: ('cb_person_cred_hist_length',)
# Matriz de Confusión (MC):
#  [[5074 1257]
#  [1427  388]]
# Exactitud (E): 0.6705131352811196
# Precisión (P): 0.2358662613981763
# Sensibilidad (S): 0.2137741046831956
# F1 Score (F1): 0.22427745664739884
# Tiempo de generación del modelo: 0.006007194519042969
# Tiempo de prueba del modelo: 0.5633580684661865
# --------------------------------------------------
# Columnas: ('loan_grade',)
# Matriz de Confusión (MC):
#  [[5857  474]
#  [1045  770]]
# Exactitud (E): 0.8135281119567886
# Precisión (P): 0.6189710610932476
# Sensibilidad (S): 0.42424242424242425
# F1 Score (F1): 0.5034324942791762
# Tiempo de generación del modelo: 0.006223201751708984
# Tiempo de prueba del modelo: 0.8459954261779785
# --------------------------------------------------
# Columnas: ('person_age', 'person_income')
# Matriz de Confusión (MC):
#  [[5646  685]
#  [1164  651]]
# Exactitud (E): 0.7730174318684017
# Precisión (P): 0.48727544910179643
# Sensibilidad (S): 0.3586776859504132
# F1 Score (F1): 0.41320215804506505
# Tiempo de generación del modelo: 0.010569095611572266
# Tiempo de prueba del modelo: 0.32941579818725586
# --------------------------------------------------
# Columnas: ('person_age', 'cb_person_cred_hist_length')
# Matriz de Confusión (MC):
#  [[5622  709]
#  [1590  225]]
# Exactitud (E): 0.7177755953842376
# Precisión (P): 0.24089935760171305
# Sensibilidad (S): 0.12396694214876033
# F1 Score (F1): 0.1636958894143325
# Tiempo de generación del modelo: 0.011016130447387695
# Tiempo de prueba del modelo: 0.37862491607666016
# --------------------------------------------------
# Columnas: ('person_age', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5873  458]
#  [1301  514]]
# Exactitud (E): 0.7840657991652344
# Precisión (P): 0.5288065843621399
# Sensibilidad (S): 0.2831955922865014
# F1 Score (F1): 0.3688554000717617
# Tiempo de generación del modelo: 0.011204242706298828
# Tiempo de prueba del modelo: 0.3722665309906006
# --------------------------------------------------
# Columnas: ('person_income', 'cb_person_cred_hist_length')
# Matriz de Confusión (MC):
#  [[5588  743]
#  [1164  651]]
# Exactitud (E): 0.7658973729437761
# Precisión (P): 0.46700143472022954
# Sensibilidad (S): 0.3586776859504132
# F1 Score (F1): 0.40573387348083517
# Tiempo de generación del modelo: 0.011192560195922852
# Tiempo de prueba del modelo: 0.3542156219482422
# --------------------------------------------------
# Columnas: ('person_income', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5760  571]
#  [ 954  861]]
# Exactitud (E): 0.8127915541369998
# Precisión (P): 0.6012569832402235
# Sensibilidad (S): 0.4743801652892562
# F1 Score (F1): 0.530335694487219
# Tiempo de generación del modelo: 0.011276721954345703
# Tiempo de prueba del modelo: 0.3356454372406006
# --------------------------------------------------
# Columnas: ('cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5859  472]
#  [1196  619]]
# Exactitud (E): 0.7952369260986988
# Precisión (P): 0.5673693858845096
# Sensibilidad (S): 0.3410468319559229
# F1 Score (F1): 0.42601514108740535
# Tiempo de generación del modelo: 0.011267900466918945
# Tiempo de prueba del modelo: 0.39893031120300293
# --------------------------------------------------
# Columnas: ('person_age', 'person_income', 'cb_person_cred_hist_length')
# Matriz de Confusión (MC):
#  [[5618  713]
#  [1159  656]]
# Exactitud (E): 0.7701939602258777
# Precisión (P): 0.47918188458729
# Sensibilidad (S): 0.36143250688705236
# F1 Score (F1): 0.41206030150753775
# Tiempo de generación del modelo: 0.013207197189331055
# Tiempo de prueba del modelo: 0.33225536346435547
# --------------------------------------------------
# Columnas: ('person_age', 'person_income', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5780  551]
#  [1022  793]]
# Exactitud (E): 0.8068990915786889
# Precisión (P): 0.5900297619047619
# Sensibilidad (S): 0.4369146005509642
# F1 Score (F1): 0.5020576131687242
# Tiempo de generación del modelo: 0.014772176742553711
# Tiempo de prueba del modelo: 0.33434510231018066
# --------------------------------------------------
# Columnas: ('person_age', 'cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5680  651]
#  [1223  592]]
# Exactitud (E): 0.7699484409526148
# Precisión (P): 0.4762670957361223
# Sensibilidad (S): 0.3261707988980716
# F1 Score (F1): 0.3871811641595814
# Tiempo de generación del modelo: 0.016414880752563477
# Tiempo de prueba del modelo: 0.3553457260131836
# --------------------------------------------------
# Columnas: ('person_income', 'cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5779  552]
#  [1036  779]]
# Exactitud (E): 0.8050576970292168
# Precisión (P): 0.585274229902329
# Sensibilidad (S): 0.42920110192837463
# F1 Score (F1): 0.49523204068658616
# Tiempo de generación del modelo: 0.01539754867553711
# Tiempo de prueba del modelo: 0.3359699249267578
# --------------------------------------------------
# Columnas: ('person_age', 'person_income', 'cb_person_cred_hist_length', 'loan_grade')
# Matriz de Confusión (MC):
#  [[5755  576]
#  [1053  762]]
# Exactitud (E): 0.8000245519273262
# Precisión (P): 0.5695067264573991
# Sensibilidad (S): 0.41983471074380163
# F1 Score (F1): 0.48334919124643194
# Tiempo de generación del modelo: 0.017172813415527344
# Tiempo de prueba del modelo: 0.33989453315734863
# --------------------------------------------------
